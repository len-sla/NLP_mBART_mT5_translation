# %% [markdown]
# # Using preprocessed files french to english  for automatic translation MarianMTModel

# %% [markdown]
# # 1. Installing required libraries

# %%
# Install transformers library.
# !pip install -q git+https://github.com/huggingface/transformers.git
# Install helper functions.
# !pip install -q git+https://github.com/gmihaila/ml_things.git
# !pip install sentencepiece #required by Marian
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 895 kB 5.1 MB/s
#      |████████████████████████████████| 6.8 MB 52.2 MB/s
#      |████████████████████████████████| 596 kB 63.7 MB/s
#      |████████████████████████████████| 67 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 64 kB 1.9 MB/s
#      |████████████████████████████████| 11.2 MB 10.5 MB/s
#      |████████████████████████████████| 890 kB 61.9 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
#      |████████████████████████████████| 1.2 MB 5.1 MB/s
# ...

# %%
from transformers import MarianMTModel, MarianTokenizer
from transformers import AutoModelWithLMHead
from transformers import pipeline
import torch

from IPython.display import HTML
from IPython.display import Image

from tqdm import tqdm

# %% [markdown]
# # 2. Mounting google drive

# %%
#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 3. Initiating auxilary funcions

# %%
# model = AutoModelWithLMHead.from_pretrained("t5-base") #loading t5 model in translation mode eng->de
# translator = pipeline("translation_en_to_de")
# FRENCH==> ENGLISH
model_name = 'Helsinki-NLP/opus-mt-fr-en'  #loading marian  model translator fr->en
tokenizer = MarianTokenizer.from_pretrained(model_name)
model_m = MarianMTModel.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/784k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/760k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/287M [00:00<?, ?B/s]

# %%
# FRENCH==> POLISH
model_name = 'Helsinki-NLP/opus-mt-fr-en'  #loading marian  model translator fr->en
tokenizer = MarianTokenizer.from_pretrained(model_name)
model_m = MarianMTModel.from_pretrained(model_name)

# %% [markdown]
# # 4

# %%
def temp_list(text_out):
  text_all=[]
  next_line=''
  dot_line='...................................'
  text_all.append(next_line)
  text_all.append(dot_line)
  for t in text_out:
    text_all.append(t)
  return text_all

temp_de =[]
file_name= '/content/drive/MyDrive/mT/fr_out.txt'
def save_list_to_file(file_name, temp_lista=temp_de):
    with open(file_name, 'a') as f:
        for item in temp_lista:
            f.write("%s\n" % item)

def translate_fr_to_en(src_text):
    translated = model_m.generate(**tokenizer.prepare_seq2seq_batch(src_text, return_tensors="pt"))
    tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
    return tgt_text
    
# def translate_ge_to_pl(src_text):
#     translated = model_m.generate(**tokenizer.prepare_seq2seq_batch(src_text, return_tensors="pt"))
#     tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
    
#     print(tgt_text)
    return tgt_text

def trans_en_de(text_out):
  temp=[]
  for text in text_out:
    text_out_de= translator(text)

    src_text= text_out_de[0]['translation_text']
    temp.append(src_text)
  return temp

# %%
#@title 2a.Translating preprocessed( new line \n every sentence) txt file to english { display-mode: "form" }

fr_text_file = "/content/drive/MyDrive/mT/fr_relined.txt" #@param [""] {allow-input: true}


# text_file= file_name

if len(fr_text_file) >0:
  output_en= fr_text_file[:-4]+'_en.txt'
  print('Text file {} will be translated  to {} '.format(fr_text_file,output_en))

  lines=[]
  with open(fr_text_file) as file :
    for line in file :
      line.strip()
      lines.append(line)
    
  print( '\n 1. ==== > Translating to english ...')
  lines_en =[]
  for l in tqdm(lines):
    text_out_en= translate_fr_to_en(l)
    for t in text_out_en:
      lines_en.append(t)

  #writing list to file attaching after every list item end of line sign \n
  save_list_to_file(output_en, temp_lista=lines_en)
  print('\n =====> File  {} was saved'.format(output_en))

  


else :
  print( 'You need to give input text file')
# Out:
# Text file /content/drive/MyDrive/mT/fr_relined.txt will be translated  to /content/drive/MyDrive/mT/fr_relined_en.txt
#
#  1. ==== > Translating to english ...
#   0%|          | 0/17 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3447: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
# ...

# %%
French version

# %%
Certains lundis de la toute fin novembre, ou du début de décembre, surtout lorsqu’on est célibataire, on a la sensation d’être dans le couloir de la mort. Les vacances d’été sont depuis longtemps oubliées, la nouvelle année est encore loin ; la proximité du néant est inhabituelle.

Le lundi 23 novembre, Bastien Doutremont décida de se rendre au travail en métro. En descendant à la station Porte de Clichy, il se retrouva en face de cette inscription dont lui avaient parlé plusieurs de ses collègues les jours précédents. Il était un peu plus de dix heures du matin ; le quai était désert.

Depuis son adolescence, il s’intéressait aux graffitis du métro parisien. Il les prenait souvent en photo, avec son iPhone désuet – on devait en être à la génération 23, il s’était arrêté à la 11. Il classait ses photos par stations et par lignes, de nombreux dossiers sur son ordinateur y étaient consacrés. C’était un hobby si l’on veut, mais il préférait l’expression en principe plus douce, mais au fond plus brutale, de passe-temps. Un de ses graffitis préfé-

rés était d’ailleurs cette inscription, en lettres penchées

# %%
English version

# %%
Some Mondays of late November, or early December, especially when you're single, you feel like you're on death row.
Summer holidays have long been forgotten, the new year is still far away; the proximity to nothingness is unusual.
On Monday, November 23, Bastien Doutremont decided to go to work by metro.
On his way down to Porte de Clichy station, he found himself in front of this inscription, which several of his colleagues had told him about the previous days.
It was a little over ten o'clock in the morning; the wharf was deserted.
Since his teens, he had been interested in the graffiti of the Parisian metro.
He often took pictures of them, with his old iPhone – we had to be in generation 23, he had stopped at 11.
He classified his photos by stations and lines, many folders on his computer were dedicated to them.
He was a hobby if he wanted to, but he preferred the expression in principle softer, but in the background more brutal, of hobbies.
One of his favourite graffiti was this inscription, in bent letters
